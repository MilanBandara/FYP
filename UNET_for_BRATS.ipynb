# %% [markdown]
# <a href="https://colab.research.google.com/github/MilanBandara/FYP/blob/main/UNET_for_BRATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting Drive
from google.colab import drive
import numpy as np
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import to_categorical

# %%
#test commit

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Creating the data generator

# %%
def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("Image - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def load_msk(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("before - ",image.shape)
            image = to_categorical(image, num_classes=4)
            # print("After - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)

            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_msk(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples
            batch_start += batch_size
            batch_end += batch_size

# %% [markdown]
# #Making the data generator

# %%
train_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_data/"
train_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_data/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_validation/"
val_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_validation/"
val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 8

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,
                                val_mask_dir, val_mask_list, batch_size)

# %% [markdown]
# #Verifying the generator

# %%
#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = val_img_datagen.__next__()

# %% [markdown]
# #Visualizing the loaded images

# %%
import random
data_point = random.randint(0, batch_size)
# data_point = 3
print(data_point)
original_labels = np.expand_dims(msk[data_point,:,:,:], axis=0)
original_labels = np.argmax(original_labels, axis=3)


plt.subplot(341)
plt.imshow(img[data_point,:,:,0], cmap='gray')
plt.title('Image t1c')
plt.subplot(342)
plt.imshow(img[data_point,:,:,1], cmap='gray')
plt.title('Image t1n')
plt.subplot(343)
plt.imshow(img[data_point,:,:,2], cmap='gray')
plt.title('Image t2f')
plt.subplot(344)
plt.imshow(img[data_point,:,:,3], cmap='gray')
plt.title('Image t2w')
plt.subplot(345)
plt.imshow(msk[data_point,:,:,0], cmap='gray')
plt.title('Label_1')
plt.subplot(346)
plt.imshow(msk[data_point,:,:,1], cmap='gray')
plt.title('Label_2')
plt.subplot(347)
plt.imshow(msk[data_point,:,:,2], cmap='gray')
plt.title('Label_3')
plt.subplot(348)
plt.imshow(msk[data_point,:,:,3], cmap='gray')
plt.title('Label_4')
plt.subplot(349)
plt.imshow(original_labels.reshape((240,240)),cmap="jet")
plt.title('Complete label')
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.show()
# Out:
# 3

# %% [markdown]
# ##Attention blocks

# %%
# https://youtu.be/L5iV5BHkMzM
"""

Attention U-net:
https://arxiv.org/pdf/1804.03999.pdf

Recurrent residual Unet (R2U-Net) paper
https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
(Check fig 4.)

Note: Batch normalization should be performed over channels after a convolution,
In the following code axis is set to 3 as our inputs are of shape
[None, height, width, channel]. Channel is axis=3.

Original code from below link but heavily modified.
https://github.com/MoleImg/Attention_UNet/blob/master/AttResUNet.py
"""

import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K



'''
A few useful metrics and losses
'''

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


##############################################################
'''
Useful blocks to build Unet

conv - BN - Activation - conv - BN - Activation - Dropout (if enabled)

'''


def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).

    1. conv - BN - Activation - conv - BN - Activation
                                          - shortcut  - BN - shortcut+BN

    2. conv - BN - Activation - conv - BN
                                     - shortcut  - BN - shortcut+BN - Activation

    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %% [markdown]
# ##Attention UNET

# %%
def attention_unet_model(batch_norm = True):
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5) #deepest conv block

    #Expansive path
    #create a gating signal
    gating_6 = gating_signal(c5, 128, batch_norm = True) #feed this and c4 to attention block
    #getting the output from attention block by feeding gating signal and c4
    att_6 = attention_block(c4, gating_6, 128)
    #Conv2DTranspose the deepest block c5
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5) #this is correct
    #concatanate the upsampled block and the the output from the attention block
    u6 = concatenate([u6, att_6])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    gating_7 = gating_signal(c6, 64, batch_norm = True)
    att_7 = attention_block(c3,gating_7,64)
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, att_7])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    gating_8 = gating_signal(c7, 32, batch_norm = True)
    att_8 = attention_block(c2,gating_8,32)
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, att_8])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    gating_9 = gating_signal(c8, 16, batch_norm = True)
    att_9 = attention_block(c1,gating_9,16)
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, att_9], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
def multi_unet_model():
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
###############################################################
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_masks_reshaped_encoded),
#                                                  train_masks_reshaped_encoded)
# print("Class weights are...:", class_weights)

# %% [markdown]
# #Defining loss functions

# %%
from keras import backend as K
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)  # -1 ultiplied as we want to minimize this value as loss function

# # Typical tf.keras API usage
# import tensorflow as tf
# from focal_loss import BinaryFocalLoss,SparseCategoricalFocalLoss

# %%
# import segmentation_models_3D as sm
# # dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3]))
# focal_loss = sm.losses.CategoricalFocalLoss()
# # total_loss = dice_loss + (1 * focal_loss)

# %%
import tensorflow as tf

class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.25, gamma=4.0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def call(self, y_true, y_pred):
        """
        Inputs and targets should be of shape (batch_size, num_classes, height, width)
        """

        # Calculate the cross-entropy loss
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)

        # Calculate the scaling factor
        pt = tf.math.exp(-ce_loss)
        scaling_factor = (1 - pt) ** self.gamma

        # Calculate the Focal loss
        focal_loss = scaling_factor * ce_loss

        # Return the average Focal loss over the batch
        return tf.reduce_mean(focal_loss)

# %% [markdown]
# ##Creating a Checkpoint

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "/content/drive/MyDrive/focal/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Calculate the number of batches per epoch
import math
n_batches = 1051 / batch_size
n_batches = math.ceil(n_batches)    # round up the number of batches to the nearest whole integer

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=10*n_batches)

# %%
IMG_HEIGHT = 240
IMG_WIDTH  =  240
IMG_CHANNELS = 4

def get_model():
    return multi_unet_model()

model = get_model()
model.compile(optimizer='adam', loss= tf.keras.losses.CategoricalFocalCrossentropy(alpha=1,gamma=4), metrics=[jacard_coef])
# model.compile(optimizer='adam', loss=focal_loss, metrics=[jacard_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 4)]        0         []
#
#  conv2d (Conv2D)             (None, 240, 240, 16)         592       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 240, 240, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 240, 240, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 120, 120, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 120, 120, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 60, 60, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 30, 30, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 15, 15, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 30, 30, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 30, 30, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 30, 30, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 30, 30, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 60, 60, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 60, 60, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 60, 60, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 60, 60, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 120, 120, 32)         8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 120, 120, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 120, 120, 32)         18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 120, 120, 32)         9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 240, 240, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 240, 240, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 240, 240, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 240, 240, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 240, 240, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 240, 240, 4)          68        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1941300 (7.41 MB)
# Trainable params: 1941300 (7.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
history = model.fit(train_img_datagen,
                    steps_per_epoch=steps_per_epoch,
                    verbose=1,
                    epochs=103,
                    validation_data=val_img_datagen,
                    validation_steps=val_steps_per_epoch,
                    callbacks=[cp_callback],
                    shuffle=False)
# Out:
# Epoch 1/103
# 131/131 [==============================] - 753s 5s/step - loss: 0.0490 - jacard_coef: 0.7312 - val_loss: 0.0312 - val_jacard_coef: 0.6865
# Epoch 2/103
# 131/131 [==============================] - 26s 187ms/step - loss: 0.0267 - jacard_coef: 0.7831 - val_loss: 0.0273 - val_jacard_coef: 0.8109
# Epoch 3/103
# 131/131 [==============================] - 24s 186ms/step - loss: 0.0241 - jacard_coef: 0.7809 - val_loss: 0.0278 - val_jacard_coef: 0.7509
# Epoch 4/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0227 - jacard_coef: 0.7765 - val_loss: 0.0256 - val_jacard_coef: 0.6782
# Epoch 5/103
# 131/131 [==============================] - 24s 187ms/step - loss: 0.0219 - jacard_coef: 0.7661 - val_loss: 0.0234 - val_jacard_coef: 0.6795
# Epoch 6/103
# 131/131 [==============================] - 23s 178ms/step - loss: 0.0212 - jacard_coef: 0.7763 - val_loss: 0.0224 - val_jacard_coef: 0.6142
# Epoch 7/103
# 131/131 [==============================] - 22s 171ms/step - loss: 0.0206 - jacard_coef: 0.7608 - val_loss: 0.0236 - val_jacard_coef: 0.6970
# Epoch 8/103
# 131/131 [==============================] - 23s 177ms/step - loss: 0.0204 - jacard_coef: 0.7593 - val_loss: 0.0200 - val_jacard_coef: 0.7110
# Epoch 9/103
# 131/131 [==============================] - 24s 180ms/step - loss: 0.0190 - jacard_coef: 0.7661 - val_loss: 0.0212 - val_jacard_coef: 0.6647
# Epoch 10/103
# 131/131 [==============================] - 23s 178ms/step - loss: 0.0179 - jacard_coef: 0.7782 - val_loss: 0.0189 - val_jacard_coef: 0.7119
# Epoch 11/103
#   9/131 [=>............................] - ETA: 12s - loss: 0.0167 - jacard_coef: 0.7352
# Epoch 11: saving model to /content/drive/MyDrive/focal/cp-0011.ckpt
# 131/131 [==============================] - 29s 220ms/step - loss: 0.0163 - jacard_coef: 0.7830 - val_loss: 0.0166 - val_jacard_coef: 0.8064
# Epoch 12/103
# 131/131 [==============================] - 27s 205ms/step - loss: 0.0156 - jacard_coef: 0.7880 - val_loss: 0.0161 - val_jacard_coef: 0.7742
# Epoch 13/103
# 131/131 [==============================] - 24s 186ms/step - loss: 0.0147 - jacard_coef: 0.7907 - val_loss: 0.0144 - val_jacard_coef: 0.8060
# Epoch 14/103
# 131/131 [==============================] - 22s 165ms/step - loss: 0.0143 - jacard_coef: 0.7976 - val_loss: 0.0154 - val_jacard_coef: 0.8070
# Epoch 15/103
# 131/131 [==============================] - 25s 191ms/step - loss: 0.0138 - jacard_coef: 0.8058 - val_loss: 0.0158 - val_jacard_coef: 0.8493
# Epoch 16/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0136 - jacard_coef: 0.8103 - val_loss: 0.0155 - val_jacard_coef: 0.8498
# Epoch 17/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0130 - jacard_coef: 0.8114 - val_loss: 0.0149 - val_jacard_coef: 0.8438
# Epoch 18/103
# 131/131 [==============================] - 28s 211ms/step - loss: 0.0130 - jacard_coef: 0.8146 - val_loss: 0.0136 - val_jacard_coef: 0.8407
# Epoch 19/103
# 131/131 [==============================] - 25s 194ms/step - loss: 0.0126 - jacard_coef: 0.8154 - val_loss: 0.0195 - val_jacard_coef: 0.8857
# Epoch 20/103
# 131/131 [==============================] - 26s 197ms/step - loss: 0.0126 - jacard_coef: 0.8149 - val_loss: 0.0173 - val_jacard_coef: 0.8461
# Epoch 21/103
#  19/131 [===>..........................] - ETA: 11s - loss: 0.0112 - jacard_coef: 0.8073
# Epoch 21: saving model to /content/drive/MyDrive/focal/cp-0021.ckpt
# 131/131 [==============================] - 24s 186ms/step - loss: 0.0124 - jacard_coef: 0.8098 - val_loss: 0.0147 - val_jacard_coef: 0.8500
# Epoch 22/103
# 131/131 [==============================] - 26s 202ms/step - loss: 0.0121 - jacard_coef: 0.8179 - val_loss: 0.0156 - val_jacard_coef: 0.8523
# Epoch 23/103
# 131/131 [==============================] - 26s 201ms/step - loss: 0.0116 - jacard_coef: 0.8226 - val_loss: 0.0162 - val_jacard_coef: 0.8549
# Epoch 24/103
# 131/131 [==============================] - 26s 196ms/step - loss: 0.0117 - jacard_coef: 0.8258 - val_loss: 0.0177 - val_jacard_coef: 0.8803
# Epoch 25/103
# 131/131 [==============================] - 28s 215ms/step - loss: 0.0115 - jacard_coef: 0.8272 - val_loss: 0.0138 - val_jacard_coef: 0.8539
# Epoch 26/103
# 131/131 [==============================] - 23s 179ms/step - loss: 0.0115 - jacard_coef: 0.8269 - val_loss: 0.0126 - val_jacard_coef: 0.8533
# Epoch 27/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0109 - jacard_coef: 0.8192 - val_loss: 0.0127 - val_jacard_coef: 0.8585
# Epoch 28/103
# 131/131 [==============================] - 27s 203ms/step - loss: 0.0109 - jacard_coef: 0.8220 - val_loss: 0.0135 - val_jacard_coef: 0.8750
# Epoch 29/103
# 131/131 [==============================] - 27s 203ms/step - loss: 0.0107 - jacard_coef: 0.8289 - val_loss: 0.0109 - val_jacard_coef: 0.8717
# Epoch 30/103
# 131/131 [==============================] - 24s 185ms/step - loss: 0.0107 - jacard_coef: 0.8327 - val_loss: 0.0129 - val_jacard_coef: 0.8639
# Epoch 31/103
#  29/131 [=====>........................] - ETA: 10s - loss: 0.0092 - jacard_coef: 0.8373
# Epoch 31: saving model to /content/drive/MyDrive/focal/cp-0031.ckpt
# 131/131 [==============================] - 29s 224ms/step - loss: 0.0107 - jacard_coef: 0.8288 - val_loss: 0.0115 - val_jacard_coef: 0.8654
# Epoch 32/103
# 131/131 [==============================] - 25s 189ms/step - loss: 0.0104 - jacard_coef: 0.8363 - val_loss: 0.0123 - val_jacard_coef: 0.8691
# Epoch 33/103
# 131/131 [==============================] - 29s 220ms/step - loss: 0.0107 - jacard_coef: 0.8317 - val_loss: 0.0107 - val_jacard_coef: 0.8720
# Epoch 34/103
# 131/131 [==============================] - 23s 178ms/step - loss: 0.0105 - jacard_coef: 0.8368 - val_loss: 0.0098 - val_jacard_coef: 0.8493
# Epoch 35/103
# 131/131 [==============================] - 29s 225ms/step - loss: 0.0106 - jacard_coef: 0.8277 - val_loss: 0.0100 - val_jacard_coef: 0.8526
# Epoch 36/103
# 131/131 [==============================] - 27s 210ms/step - loss: 0.0103 - jacard_coef: 0.8293 - val_loss: 0.0101 - val_jacard_coef: 0.8448
# Epoch 37/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0101 - jacard_coef: 0.8362 - val_loss: 0.0101 - val_jacard_coef: 0.8489
# Epoch 38/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0100 - jacard_coef: 0.8368 - val_loss: 0.0103 - val_jacard_coef: 0.8447
# Epoch 39/103
# 131/131 [==============================] - 25s 189ms/step - loss: 0.0097 - jacard_coef: 0.8394 - val_loss: 0.0120 - val_jacard_coef: 0.8789
# Epoch 40/103
# 131/131 [==============================] - 27s 207ms/step - loss: 0.0096 - jacard_coef: 0.8420 - val_loss: 0.0117 - val_jacard_coef: 0.8720
# Epoch 41/103
#  39/131 [=======>......................] - ETA: 9s - loss: 0.0086 - jacard_coef: 0.8430
# Epoch 41: saving model to /content/drive/MyDrive/focal/cp-0041.ckpt
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0100 - jacard_coef: 0.8337 - val_loss: 0.0115 - val_jacard_coef: 0.8796
# Epoch 42/103
# 131/131 [==============================] - 28s 211ms/step - loss: 0.0096 - jacard_coef: 0.8460 - val_loss: 0.0120 - val_jacard_coef: 0.8703
# Epoch 43/103
# 131/131 [==============================] - 28s 211ms/step - loss: 0.0094 - jacard_coef: 0.8393 - val_loss: 0.0116 - val_jacard_coef: 0.8721
# Epoch 44/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0093 - jacard_coef: 0.8506 - val_loss: 0.0127 - val_jacard_coef: 0.8882
# Epoch 45/103
# 131/131 [==============================] - 30s 226ms/step - loss: 0.0093 - jacard_coef: 0.8487 - val_loss: 0.0113 - val_jacard_coef: 0.8894
# Epoch 46/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0091 - jacard_coef: 0.8459 - val_loss: 0.0121 - val_jacard_coef: 0.8861
# Epoch 47/103
# 131/131 [==============================] - 27s 205ms/step - loss: 0.0089 - jacard_coef: 0.8456 - val_loss: 0.0113 - val_jacard_coef: 0.8785
# Epoch 48/103
# 131/131 [==============================] - 29s 223ms/step - loss: 0.0091 - jacard_coef: 0.8428 - val_loss: 0.0099 - val_jacard_coef: 0.8907
# Epoch 49/103
# 131/131 [==============================] - 26s 199ms/step - loss: 0.0088 - jacard_coef: 0.8439 - val_loss: 0.0098 - val_jacard_coef: 0.8952
# Epoch 50/103
# 131/131 [==============================] - 25s 193ms/step - loss: 0.0089 - jacard_coef: 0.8509 - val_loss: 0.0091 - val_jacard_coef: 0.8814
# Epoch 51/103
#  49/131 [==========>...................] - ETA: 7s - loss: 0.0073 - jacard_coef: 0.8558
# Epoch 51: saving model to /content/drive/MyDrive/focal/cp-0051.ckpt
# 131/131 [==============================] - 26s 198ms/step - loss: 0.0089 - jacard_coef: 0.8482 - val_loss: 0.0110 - val_jacard_coef: 0.9003
# Epoch 52/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0089 - jacard_coef: 0.8467 - val_loss: 0.0101 - val_jacard_coef: 0.8891
# Epoch 53/103
# 131/131 [==============================] - 22s 164ms/step - loss: 0.0086 - jacard_coef: 0.8439 - val_loss: 0.0087 - val_jacard_coef: 0.8696
# Epoch 54/103
# 131/131 [==============================] - 28s 217ms/step - loss: 0.0084 - jacard_coef: 0.8464 - val_loss: 0.0095 - val_jacard_coef: 0.8242
# Epoch 55/103
# 131/131 [==============================] - 25s 189ms/step - loss: 0.0081 - jacard_coef: 0.8578 - val_loss: 0.0097 - val_jacard_coef: 0.8880
# Epoch 56/103
# 131/131 [==============================] - 24s 184ms/step - loss: 0.0081 - jacard_coef: 0.8551 - val_loss: 0.0098 - val_jacard_coef: 0.8832
# Epoch 57/103
# 131/131 [==============================] - 25s 189ms/step - loss: 0.0086 - jacard_coef: 0.8534 - val_loss: 0.0103 - val_jacard_coef: 0.8950
# Epoch 58/103
# 131/131 [==============================] - 28s 212ms/step - loss: 0.0082 - jacard_coef: 0.8553 - val_loss: 0.0110 - val_jacard_coef: 0.8779
# Epoch 59/103
# 131/131 [==============================] - 25s 190ms/step - loss: 0.0086 - jacard_coef: 0.8502 - val_loss: 0.0100 - val_jacard_coef: 0.8886
# Epoch 60/103
# 131/131 [==============================] - 23s 177ms/step - loss: 0.0086 - jacard_coef: 0.8541 - val_loss: 0.0104 - val_jacard_coef: 0.8726
# Epoch 61/103
#  59/131 [============>.................] - ETA: 7s - loss: 0.0069 - jacard_coef: 0.8595
# Epoch 61: saving model to /content/drive/MyDrive/focal/cp-0061.ckpt
# 131/131 [==============================] - 27s 205ms/step - loss: 0.0081 - jacard_coef: 0.8540 - val_loss: 0.0107 - val_jacard_coef: 0.8826
# Epoch 62/103
# 131/131 [==============================] - 26s 203ms/step - loss: 0.0081 - jacard_coef: 0.8563 - val_loss: 0.0107 - val_jacard_coef: 0.8781
# Epoch 63/103
# 131/131 [==============================] - 26s 197ms/step - loss: 0.0080 - jacard_coef: 0.8506 - val_loss: 0.0110 - val_jacard_coef: 0.8869
# Epoch 64/103
# 131/131 [==============================] - 28s 212ms/step - loss: 0.0079 - jacard_coef: 0.8580 - val_loss: 0.0113 - val_jacard_coef: 0.8998
# Epoch 65/103
# 131/131 [==============================] - 27s 206ms/step - loss: 0.0078 - jacard_coef: 0.8596 - val_loss: 0.0116 - val_jacard_coef: 0.9163
# Epoch 66/103
# 131/131 [==============================] - 25s 194ms/step - loss: 0.0078 - jacard_coef: 0.8551 - val_loss: 0.0114 - val_jacard_coef: 0.9045
# Epoch 67/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0074 - jacard_coef: 0.8671 - val_loss: 0.0116 - val_jacard_coef: 0.9015
# Epoch 68/103
# 131/131 [==============================] - 26s 200ms/step - loss: 0.0077 - jacard_coef: 0.8565 - val_loss: 0.0114 - val_jacard_coef: 0.9172
# Epoch 69/103
# 131/131 [==============================] - 25s 191ms/step - loss: 0.0075 - jacard_coef: 0.8633 - val_loss: 0.0117 - val_jacard_coef: 0.9038
# Epoch 70/103
# 131/131 [==============================] - 26s 197ms/step - loss: 0.0074 - jacard_coef: 0.8576 - val_loss: 0.0120 - val_jacard_coef: 0.8974
# Epoch 71/103
#  69/131 [==============>...............] - ETA: 6s - loss: 0.0062 - jacard_coef: 0.8712
# Epoch 71: saving model to /content/drive/MyDrive/focal/cp-0071.ckpt
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0075 - jacard_coef: 0.8518 - val_loss: 0.0107 - val_jacard_coef: 0.9112
# Epoch 72/103
# 131/131 [==============================] - 27s 207ms/step - loss: 0.0075 - jacard_coef: 0.8489 - val_loss: 0.0118 - val_jacard_coef: 0.9156
# Epoch 73/103
# 131/131 [==============================] - 28s 216ms/step - loss: 0.0076 - jacard_coef: 0.8554 - val_loss: 0.0130 - val_jacard_coef: 0.9026
# Epoch 74/103
# 131/131 [==============================] - 28s 214ms/step - loss: 0.0074 - jacard_coef: 0.8517 - val_loss: 0.0117 - val_jacard_coef: 0.8942
# Epoch 75/103
# 131/131 [==============================] - 27s 208ms/step - loss: 0.0076 - jacard_coef: 0.8533 - val_loss: 0.0115 - val_jacard_coef: 0.9079
# Epoch 76/103
# 131/131 [==============================] - 30s 229ms/step - loss: 0.0084 - jacard_coef: 0.8438 - val_loss: 0.0124 - val_jacard_coef: 0.8888
# Epoch 77/103
# 131/131 [==============================] - 27s 205ms/step - loss: 0.0082 - jacard_coef: 0.8448 - val_loss: 0.0113 - val_jacard_coef: 0.8758
# Epoch 78/103
# 131/131 [==============================] - 27s 208ms/step - loss: 0.0086 - jacard_coef: 0.8314 - val_loss: 0.0112 - val_jacard_coef: 0.8833
# Epoch 79/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0075 - jacard_coef: 0.8461 - val_loss: 0.0105 - val_jacard_coef: 0.8755
# Epoch 80/103
# 131/131 [==============================] - 26s 202ms/step - loss: 0.0073 - jacard_coef: 0.8558 - val_loss: 0.0107 - val_jacard_coef: 0.8950
# Epoch 81/103
#  79/131 [=================>............] - ETA: 5s - loss: 0.0059 - jacard_coef: 0.8792
# Epoch 81: saving model to /content/drive/MyDrive/focal/cp-0081.ckpt
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0071 - jacard_coef: 0.8625 - val_loss: 0.0122 - val_jacard_coef: 0.9017
# Epoch 82/103
# 131/131 [==============================] - 26s 201ms/step - loss: 0.0069 - jacard_coef: 0.8609 - val_loss: 0.0094 - val_jacard_coef: 0.8817
# Epoch 83/103
# 131/131 [==============================] - 28s 216ms/step - loss: 0.0074 - jacard_coef: 0.8497 - val_loss: 0.0109 - val_jacard_coef: 0.8790
# Epoch 84/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0068 - jacard_coef: 0.8562 - val_loss: 0.0092 - val_jacard_coef: 0.8748
# Epoch 85/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0064 - jacard_coef: 0.8665 - val_loss: 0.0093 - val_jacard_coef: 0.8700
# Epoch 86/103
# 131/131 [==============================] - 25s 193ms/step - loss: 0.0065 - jacard_coef: 0.8619 - val_loss: 0.0097 - val_jacard_coef: 0.8618
# Epoch 87/103
# 131/131 [==============================] - 26s 199ms/step - loss: 0.0068 - jacard_coef: 0.8481 - val_loss: 0.0094 - val_jacard_coef: 0.8726
# Epoch 88/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0069 - jacard_coef: 0.8603 - val_loss: 0.0093 - val_jacard_coef: 0.8876
# Epoch 89/103
# 131/131 [==============================] - 28s 212ms/step - loss: 0.0063 - jacard_coef: 0.8678 - val_loss: 0.0090 - val_jacard_coef: 0.8812
# Epoch 90/103
# 131/131 [==============================] - 28s 211ms/step - loss: 0.0064 - jacard_coef: 0.8482 - val_loss: 0.0087 - val_jacard_coef: 0.8758
# Epoch 91/103
#  89/131 [===================>..........] - ETA: 4s - loss: 0.0052 - jacard_coef: 0.8715
# Epoch 91: saving model to /content/drive/MyDrive/focal/cp-0091.ckpt
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0062 - jacard_coef: 0.8590 - val_loss: 0.0088 - val_jacard_coef: 0.8727
# Epoch 92/103
# 131/131 [==============================] - 26s 201ms/step - loss: 0.0062 - jacard_coef: 0.8680 - val_loss: 0.0105 - val_jacard_coef: 0.8831
# Epoch 93/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0061 - jacard_coef: 0.8687 - val_loss: 0.0110 - val_jacard_coef: 0.8872
# Epoch 94/103
# 131/131 [==============================] - 25s 191ms/step - loss: 0.0064 - jacard_coef: 0.8601 - val_loss: 0.0129 - val_jacard_coef: 0.8702
# Epoch 95/103
# 131/131 [==============================] - 22s 172ms/step - loss: 0.0061 - jacard_coef: 0.8674 - val_loss: 0.0128 - val_jacard_coef: 0.8963
# Epoch 96/103
# 131/131 [==============================] - 25s 187ms/step - loss: 0.0061 - jacard_coef: 0.8675 - val_loss: 0.0135 - val_jacard_coef: 0.8961
# Epoch 97/103
# 131/131 [==============================] - 28s 214ms/step - loss: 0.0059 - jacard_coef: 0.8593 - val_loss: 0.0135 - val_jacard_coef: 0.8836
# Epoch 98/103
# 131/131 [==============================] - 25s 191ms/step - loss: 0.0062 - jacard_coef: 0.8655 - val_loss: 0.0133 - val_jacard_coef: 0.8460
# Epoch 99/103
# 131/131 [==============================] - 24s 180ms/step - loss: 0.0070 - jacard_coef: 0.8642 - val_loss: 0.0123 - val_jacard_coef: 0.8271
# Epoch 100/103
# 131/131 [==============================] - 25s 192ms/step - loss: 0.0069 - jacard_coef: 0.8512 - val_loss: 0.0150 - val_jacard_coef: 0.8334
# Epoch 101/103
#  99/131 [=====================>........] - ETA: 3s - loss: 0.0056 - jacard_coef: 0.8628
# Epoch 101: saving model to /content/drive/MyDrive/focal/cp-0101.ckpt
# 131/131 [==============================] - 28s 215ms/step - loss: 0.0064 - jacard_coef: 0.8536 - val_loss: 0.0161 - val_jacard_coef: 0.8752
# Epoch 102/103
# 131/131 [==============================] - 23s 175ms/step - loss: 0.0060 - jacard_coef: 0.8627 - val_loss: 0.0136 - val_jacard_coef: 0.8632
# Epoch 103/103
# 131/131 [==============================] - 27s 210ms/step - loss: 0.0063 - jacard_coef: 0.8637 - val_loss: 0.0133 - val_jacard_coef: 0.8644

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
for i in history.history.items():
  print(i)

# %%
acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
np.save("/content/drive/MyDrive/focal/training_loss.npy",np.array(loss))
np.save("/content/drive/MyDrive/focal/val_loss.npy",np.array(val_loss))
np.save("/content/drive/MyDrive/focal/training_jaccard.npy",np.array(acc))
np.save("/content/drive/MyDrive/focal/val_jaccard.npy",np.array(val_acc))
np.save("/content/drive/MyDrive/focal/epochs.npy",range(1, len(np.array(loss)) + 1))

# %%
# loss_1 = np.load("/content/drive/MyDrive/small_UNET_models/training_loss.npy")
# epoch_1 = np.load("/content/drive/MyDrive/small_UNET_models/epochs.npy")

# plt.plot(epoch_1, loss_1, 'y', label='Training loss')
# # plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
img, msk = val_img_datagen.__next__()

# %% [markdown]
# ##making predictions on test dataset

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img)-1)#6 is good
# test_img_number = 6
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(233)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# focal_loss = FocalLoss()
# loss = focal_loss.call(ground_truth, predicted_img)
# print(loss)
# # IOU = jacard_coef(ground_truth, predicted_img)
# # print(IOU)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# (1, 240, 240, 4)
# (240, 240, 4)

# %% [markdown]
# ##Loading the last checkpoint

# %%
model = multi_unet_model()
model.compile(optimizer='adam', loss= FocalLoss(), metrics=[jacard_coef])

# Load the previously saved weights
model.load_weights("/content/drive/MyDrive/focal/cp-0091.ckpt")

# %%
img, msk = val_img_datagen.__next__()

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
#img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img)-1)#6 is good
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image 1')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Testing Image 2')
plt.imshow(test_img[:,:,1], cmap='gray') #only the first channel is displayed

plt.subplot(233)
plt.title('Testing Image 3')
plt.imshow(test_img[:,:,2], cmap='gray') #only the first channel is displayed

plt.subplot(234)
plt.title('Testing Image 4')
plt.imshow(test_img[:,:,3], cmap='gray') #only the first channel is displayed

plt.subplot(235)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(236)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# (1, 240, 240, 4)
# (240, 240, 4)
