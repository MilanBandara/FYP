# %%
# Mounting Drive
from google.colab import drive
import numpy as np
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import to_categorical

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Creating the data generator

# %%
def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("Image - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def load_msk(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("before - ",image.shape)
            image = to_categorical(image, num_classes=4)
            # print("After - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)

            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_msk(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples
            batch_start += batch_size
            batch_end += batch_size

# %% [markdown]
# #Making the data generator

# %%
train_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_data/"
train_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_data/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_validation/"
val_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_validation/"
val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 8

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,
                                val_mask_dir, val_mask_list, batch_size)

# %% [markdown]
# #Verifying the generator

# %%
#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = val_img_datagen.__next__()

# %% [markdown]
# #Visualizing the loaded images

# %%
import random
data_point = random.randint(0, batch_size)
# data_point = 3
print(data_point)
original_labels = np.expand_dims(msk[data_point,:,:,:], axis=0)
original_labels = np.argmax(original_labels, axis=3)


plt.subplot(341)
plt.imshow(img[data_point,:,:,0], cmap='gray')
plt.title('Image t1c')
plt.subplot(342)
plt.imshow(img[data_point,:,:,1], cmap='gray')
plt.title('Image t1n')
plt.subplot(343)
plt.imshow(img[data_point,:,:,2], cmap='gray')
plt.title('Image t2f')
plt.subplot(344)
plt.imshow(img[data_point,:,:,3], cmap='gray')
plt.title('Image t2w')
plt.subplot(345)
plt.imshow(msk[data_point,:,:,0], cmap='gray')
plt.title('Label_1')
plt.subplot(346)
plt.imshow(msk[data_point,:,:,1], cmap='gray')
plt.title('Label_2')
plt.subplot(347)
plt.imshow(msk[data_point,:,:,2], cmap='gray')
plt.title('Label_3')
plt.subplot(348)
plt.imshow(msk[data_point,:,:,3], cmap='gray')
plt.title('Label_4')
plt.subplot(349)
plt.imshow(original_labels.reshape((240,240)),cmap="jet")
plt.title('Complete label')
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.show()
# Out:
# 4

# %% [markdown]
# ##Attention blocks

# %%
# https://youtu.be/L5iV5BHkMzM
"""

Attention U-net:
https://arxiv.org/pdf/1804.03999.pdf

Recurrent residual Unet (R2U-Net) paper
https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
(Check fig 4.)

Note: Batch normalization should be performed over channels after a convolution,
In the following code axis is set to 3 as our inputs are of shape
[None, height, width, channel]. Channel is axis=3.

Original code from below link but heavily modified.
https://github.com/MoleImg/Attention_UNet/blob/master/AttResUNet.py
"""

import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K



'''
A few useful metrics and losses
'''

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


##############################################################
'''
Useful blocks to build Unet

conv - BN - Activation - conv - BN - Activation - Dropout (if enabled)

'''


def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).

    1. conv - BN - Activation - conv - BN - Activation
                                          - shortcut  - BN - shortcut+BN

    2. conv - BN - Activation - conv - BN
                                     - shortcut  - BN - shortcut+BN - Activation

    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %% [markdown]
# ##Attention UNET

# %%
def attention_unet_model(batch_norm = True):
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5) #deepest conv block

    #Expansive path
    #create a gating signal
    gating_6 = gating_signal(c5, 128, batch_norm = True) #feed this and c4 to attention block
    #getting the output from attention block by feeding gating signal and c4
    att_6 = attention_block(c4, gating_6, 128)
    #Conv2DTranspose the deepest block c5
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5) #this is correct
    #concatanate the upsampled block and the the output from the attention block
    u6 = concatenate([u6, att_6])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    gating_7 = gating_signal(c6, 64, batch_norm = True)
    att_7 = attention_block(c3,gating_7,64)
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, att_7])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    gating_8 = gating_signal(c7, 32, batch_norm = True)
    att_8 = attention_block(c2,gating_8,32)
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, att_8])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    gating_9 = gating_signal(c8, 16, batch_norm = True)
    att_9 = attention_block(c1,gating_9,16)
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, att_9], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
def multi_unet_model():
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
###############################################################
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_masks_reshaped_encoded),
#                                                  train_masks_reshaped_encoded)
# print("Class weights are...:", class_weights)

# %% [markdown]
# #Defining loss functions

# %%
from keras import backend as K
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)  # -1 ultiplied as we want to minimize this value as loss function

# # Typical tf.keras API usage
# import tensorflow as tf
# from focal_loss import BinaryFocalLoss,SparseCategoricalFocalLoss

# %%
# import segmentation_models_3D as sm
# # dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3]))
# focal_loss = sm.losses.CategoricalFocalLoss()
# # total_loss = dice_loss + (1 * focal_loss)

# %%
import tensorflow as tf

class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.25, gamma=4.0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def call(self, y_true, y_pred):
        """
        Inputs and targets should be of shape (batch_size, num_classes, height, width)
        """

        # Calculate the cross-entropy loss
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)

        # Calculate the scaling factor
        pt = tf.math.exp(-ce_loss)
        scaling_factor = (1 - pt) ** self.gamma

        # Calculate the Focal loss
        focal_loss = scaling_factor * ce_loss

        # Return the average Focal loss over the batch
        return tf.reduce_mean(focal_loss)

# %% [markdown]
# ##Creating a Checkpoint

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "/content/drive/MyDrive/focal/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Calculate the number of batches per epoch
import math
n_batches = 1051 / batch_size
n_batches = math.ceil(n_batches)    # round up the number of batches to the nearest whole integer

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=10*n_batches)

# %%
IMG_HEIGHT = 240
IMG_WIDTH  =  240
IMG_CHANNELS = 4

def get_model():
    return multi_unet_model()

model = get_model()
model.compile(optimizer='adam', loss= FocalLoss(), metrics=[jacard_coef])
# model.compile(optimizer='adam', loss=focal_loss, metrics=[jacard_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 4)]        0         []
#
#  conv2d (Conv2D)             (None, 240, 240, 16)         592       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 240, 240, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 240, 240, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 120, 120, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 120, 120, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 60, 60, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 30, 30, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 15, 15, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 30, 30, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 30, 30, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 30, 30, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 30, 30, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 60, 60, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 60, 60, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 60, 60, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 60, 60, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 120, 120, 32)         8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 120, 120, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 120, 120, 32)         18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 120, 120, 32)         9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 240, 240, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 240, 240, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 240, 240, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 240, 240, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 240, 240, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 240, 240, 4)          68        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1941300 (7.41 MB)
# Trainable params: 1941300 (7.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
history = model.fit(train_img_datagen,
                    steps_per_epoch=steps_per_epoch,
                    verbose=1,
                    epochs=103,
                    validation_data=val_img_datagen,
                    validation_steps=val_steps_per_epoch,
                    callbacks=[cp_callback],
                    shuffle=False)
# Out:
# Epoch 1/103
# 131/131 [==============================] - 745s 6s/step - loss: 0.0701 - jacard_coef: 0.6773 - val_loss: 0.0499 - val_jacard_coef: 0.8236
# Epoch 2/103
# 131/131 [==============================] - 24s 173ms/step - loss: 0.0266 - jacard_coef: 0.7683 - val_loss: 0.0258 - val_jacard_coef: 0.7901
# Epoch 3/103
# 131/131 [==============================] - 22s 167ms/step - loss: 0.0247 - jacard_coef: 0.7600 - val_loss: 0.0247 - val_jacard_coef: 0.7623
# Epoch 4/103
# 131/131 [==============================] - 22s 169ms/step - loss: 0.0227 - jacard_coef: 0.7692 - val_loss: 0.0274 - val_jacard_coef: 0.6451
# Epoch 5/103
# 131/131 [==============================] - 21s 162ms/step - loss: 0.0215 - jacard_coef: 0.7759 - val_loss: 0.0272 - val_jacard_coef: 0.6146
# Epoch 6/103
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0205 - jacard_coef: 0.7810 - val_loss: 0.0258 - val_jacard_coef: 0.6005
# Epoch 7/103
# 131/131 [==============================] - 37s 287ms/step - loss: 0.0197 - jacard_coef: 0.7877 - val_loss: 0.0243 - val_jacard_coef: 0.6290
# Epoch 8/103
# 131/131 [==============================] - 19s 149ms/step - loss: 0.0188 - jacard_coef: 0.7901 - val_loss: 0.0232 - val_jacard_coef: 0.6511
# Epoch 9/103
# 131/131 [==============================] - 17s 128ms/step - loss: 0.0189 - jacard_coef: 0.7885 - val_loss: 0.0235 - val_jacard_coef: 0.6126
# Epoch 10/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0176 - jacard_coef: 0.7919 - val_loss: 0.0191 - val_jacard_coef: 0.7232
# Epoch 11/103
#   9/131 [=>............................] - ETA: 11s - loss: 0.0163 - jacard_coef: 0.7163
# Epoch 11: saving model to /content/drive/MyDrive/focal/cp-0011.ckpt
# 131/131 [==============================] - 15s 115ms/step - loss: 0.0170 - jacard_coef: 0.7972 - val_loss: 0.0186 - val_jacard_coef: 0.7185
# Epoch 12/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0161 - jacard_coef: 0.7967 - val_loss: 0.0168 - val_jacard_coef: 0.7661
# Epoch 13/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0152 - jacard_coef: 0.8076 - val_loss: 0.0162 - val_jacard_coef: 0.7890
# Epoch 14/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0152 - jacard_coef: 0.8044 - val_loss: 0.0172 - val_jacard_coef: 0.8088
# Epoch 15/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0147 - jacard_coef: 0.8070 - val_loss: 0.0186 - val_jacard_coef: 0.8361
# Epoch 16/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0143 - jacard_coef: 0.8111 - val_loss: 0.0208 - val_jacard_coef: 0.8571
# Epoch 17/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0139 - jacard_coef: 0.8103 - val_loss: 0.0173 - val_jacard_coef: 0.8567
# Epoch 18/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0131 - jacard_coef: 0.8222 - val_loss: 0.0178 - val_jacard_coef: 0.8580
# Epoch 19/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0127 - jacard_coef: 0.8258 - val_loss: 0.0154 - val_jacard_coef: 0.8571
# Epoch 20/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0125 - jacard_coef: 0.8264 - val_loss: 0.0156 - val_jacard_coef: 0.8437
# Epoch 21/103
#  19/131 [===>..........................] - ETA: 11s - loss: 0.0123 - jacard_coef: 0.8178
# Epoch 21: saving model to /content/drive/MyDrive/focal/cp-0021.ckpt
# 131/131 [==============================] - 15s 116ms/step - loss: 0.0120 - jacard_coef: 0.8274 - val_loss: 0.0135 - val_jacard_coef: 0.8398
# Epoch 22/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0117 - jacard_coef: 0.8282 - val_loss: 0.0131 - val_jacard_coef: 0.8272
# Epoch 23/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0113 - jacard_coef: 0.8316 - val_loss: 0.0132 - val_jacard_coef: 0.8063
# Epoch 24/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0111 - jacard_coef: 0.8245 - val_loss: 0.0135 - val_jacard_coef: 0.7822
# Epoch 25/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0108 - jacard_coef: 0.8257 - val_loss: 0.0119 - val_jacard_coef: 0.8075
# Epoch 26/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0107 - jacard_coef: 0.8252 - val_loss: 0.0118 - val_jacard_coef: 0.7878
# Epoch 27/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0103 - jacard_coef: 0.8320 - val_loss: 0.0112 - val_jacard_coef: 0.8118
# Epoch 28/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0101 - jacard_coef: 0.8287 - val_loss: 0.0105 - val_jacard_coef: 0.8109
# Epoch 29/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0098 - jacard_coef: 0.8330 - val_loss: 0.0114 - val_jacard_coef: 0.8041
# Epoch 30/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0105 - jacard_coef: 0.8327 - val_loss: 0.0116 - val_jacard_coef: 0.8183
# Epoch 31/103
#  29/131 [=====>........................] - ETA: 9s - loss: 0.0092 - jacard_coef: 0.8353
# Epoch 31: saving model to /content/drive/MyDrive/focal/cp-0031.ckpt
# 131/131 [==============================] - 15s 114ms/step - loss: 0.0101 - jacard_coef: 0.8369 - val_loss: 0.0109 - val_jacard_coef: 0.8413
# Epoch 32/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0096 - jacard_coef: 0.8347 - val_loss: 0.0111 - val_jacard_coef: 0.8213
# Epoch 33/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0095 - jacard_coef: 0.8344 - val_loss: 0.0113 - val_jacard_coef: 0.8293
# Epoch 34/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0093 - jacard_coef: 0.8387 - val_loss: 0.0111 - val_jacard_coef: 0.8338
# Epoch 35/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0093 - jacard_coef: 0.8380 - val_loss: 0.0103 - val_jacard_coef: 0.8461
# Epoch 36/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0092 - jacard_coef: 0.8351 - val_loss: 0.0107 - val_jacard_coef: 0.8043
# Epoch 37/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0088 - jacard_coef: 0.8389 - val_loss: 0.0106 - val_jacard_coef: 0.8543
# Epoch 38/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0088 - jacard_coef: 0.8428 - val_loss: 0.0108 - val_jacard_coef: 0.8647
# Epoch 39/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0087 - jacard_coef: 0.8445 - val_loss: 0.0119 - val_jacard_coef: 0.9024
# Epoch 40/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0089 - jacard_coef: 0.8387 - val_loss: 0.0106 - val_jacard_coef: 0.8761
# Epoch 41/103
#  39/131 [=======>......................] - ETA: 9s - loss: 0.0074 - jacard_coef: 0.8480
# Epoch 41: saving model to /content/drive/MyDrive/focal/cp-0041.ckpt
# 131/131 [==============================] - 15s 116ms/step - loss: 0.0087 - jacard_coef: 0.8400 - val_loss: 0.0113 - val_jacard_coef: 0.8350
# Epoch 42/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0089 - jacard_coef: 0.8364 - val_loss: 0.0107 - val_jacard_coef: 0.8626
# Epoch 43/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0083 - jacard_coef: 0.8429 - val_loss: 0.0118 - val_jacard_coef: 0.8591
# Epoch 44/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0083 - jacard_coef: 0.8402 - val_loss: 0.0107 - val_jacard_coef: 0.8905
# Epoch 45/103
# 131/131 [==============================] - 14s 111ms/step - loss: 0.0086 - jacard_coef: 0.8453 - val_loss: 0.0100 - val_jacard_coef: 0.8388
# Epoch 46/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0080 - jacard_coef: 0.8448 - val_loss: 0.0099 - val_jacard_coef: 0.8557
# Epoch 47/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0080 - jacard_coef: 0.8433 - val_loss: 0.0138 - val_jacard_coef: 0.8381
# Epoch 48/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0080 - jacard_coef: 0.8527 - val_loss: 0.0110 - val_jacard_coef: 0.8691
# Epoch 49/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0077 - jacard_coef: 0.8501 - val_loss: 0.0137 - val_jacard_coef: 0.8582
# Epoch 50/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0079 - jacard_coef: 0.8487 - val_loss: 0.0105 - val_jacard_coef: 0.8651
# Epoch 51/103
#  49/131 [==========>...................] - ETA: 7s - loss: 0.0065 - jacard_coef: 0.8671
# Epoch 51: saving model to /content/drive/MyDrive/focal/cp-0051.ckpt
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0080 - jacard_coef: 0.8500 - val_loss: 0.0127 - val_jacard_coef: 0.8253
# Epoch 52/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0082 - jacard_coef: 0.8461 - val_loss: 0.0117 - val_jacard_coef: 0.8436
# Epoch 53/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0076 - jacard_coef: 0.8519 - val_loss: 0.0118 - val_jacard_coef: 0.8549
# Epoch 54/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0074 - jacard_coef: 0.8521 - val_loss: 0.0138 - val_jacard_coef: 0.8182
# Epoch 55/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0080 - jacard_coef: 0.8439 - val_loss: 0.0098 - val_jacard_coef: 0.8565
# Epoch 56/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0081 - jacard_coef: 0.8444 - val_loss: 0.0151 - val_jacard_coef: 0.8417
# Epoch 57/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0091 - jacard_coef: 0.8428 - val_loss: 0.0118 - val_jacard_coef: 0.7699
# Epoch 58/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0086 - jacard_coef: 0.8393 - val_loss: 0.0131 - val_jacard_coef: 0.8461
# Epoch 59/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0077 - jacard_coef: 0.8472 - val_loss: 0.0103 - val_jacard_coef: 0.8595
# Epoch 60/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0070 - jacard_coef: 0.8560 - val_loss: 0.0098 - val_jacard_coef: 0.8572
# Epoch 61/103
#  59/131 [============>.................] - ETA: 6s - loss: 0.0062 - jacard_coef: 0.8637
# Epoch 61: saving model to /content/drive/MyDrive/focal/cp-0061.ckpt
# 131/131 [==============================] - 15s 115ms/step - loss: 0.0071 - jacard_coef: 0.8534 - val_loss: 0.0109 - val_jacard_coef: 0.8520
# Epoch 62/103
# 131/131 [==============================] - 14s 107ms/step - loss: 0.0072 - jacard_coef: 0.8505 - val_loss: 0.0108 - val_jacard_coef: 0.8161
# Epoch 63/103
# 131/131 [==============================] - 14s 111ms/step - loss: 0.0070 - jacard_coef: 0.8479 - val_loss: 0.0106 - val_jacard_coef: 0.8647
# Epoch 64/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0072 - jacard_coef: 0.8535 - val_loss: 0.0112 - val_jacard_coef: 0.8499
# Epoch 65/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0070 - jacard_coef: 0.8530 - val_loss: 0.0109 - val_jacard_coef: 0.8607
# Epoch 66/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0071 - jacard_coef: 0.8554 - val_loss: 0.0105 - val_jacard_coef: 0.8743
# Epoch 67/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0072 - jacard_coef: 0.8526 - val_loss: 0.0110 - val_jacard_coef: 0.8708
# Epoch 68/103
# 131/131 [==============================] - 14s 111ms/step - loss: 0.0074 - jacard_coef: 0.8489 - val_loss: 0.0101 - val_jacard_coef: 0.8961
# Epoch 69/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0066 - jacard_coef: 0.8623 - val_loss: 0.0117 - val_jacard_coef: 0.8798
# Epoch 70/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0069 - jacard_coef: 0.8515 - val_loss: 0.0114 - val_jacard_coef: 0.8731
# Epoch 71/103
#  69/131 [==============>...............] - ETA: 5s - loss: 0.0059 - jacard_coef: 0.8450
# Epoch 71: saving model to /content/drive/MyDrive/focal/cp-0071.ckpt
# 131/131 [==============================] - 15s 116ms/step - loss: 0.0068 - jacard_coef: 0.8456 - val_loss: 0.0115 - val_jacard_coef: 0.8883
# Epoch 72/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0066 - jacard_coef: 0.8587 - val_loss: 0.0119 - val_jacard_coef: 0.8734
# Epoch 73/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0063 - jacard_coef: 0.8620 - val_loss: 0.0112 - val_jacard_coef: 0.8854
# Epoch 74/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0064 - jacard_coef: 0.8599 - val_loss: 0.0120 - val_jacard_coef: 0.8703
# Epoch 75/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0063 - jacard_coef: 0.8568 - val_loss: 0.0124 - val_jacard_coef: 0.8761
# Epoch 76/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0063 - jacard_coef: 0.8583 - val_loss: 0.0128 - val_jacard_coef: 0.8759
# Epoch 77/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0066 - jacard_coef: 0.8565 - val_loss: 0.0103 - val_jacard_coef: 0.8739
# Epoch 78/103
# 131/131 [==============================] - 14s 109ms/step - loss: 0.0059 - jacard_coef: 0.8576 - val_loss: 0.0105 - val_jacard_coef: 0.8639
# Epoch 79/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0058 - jacard_coef: 0.8620 - val_loss: 0.0106 - val_jacard_coef: 0.8802
# Epoch 80/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0061 - jacard_coef: 0.8654 - val_loss: 0.0098 - val_jacard_coef: 0.8650
# Epoch 81/103
#  79/131 [=================>............] - ETA: 4s - loss: 0.0047 - jacard_coef: 0.8762
# Epoch 81: saving model to /content/drive/MyDrive/focal/cp-0081.ckpt
# 131/131 [==============================] - 15s 114ms/step - loss: 0.0056 - jacard_coef: 0.8663 - val_loss: 0.0109 - val_jacard_coef: 0.8864
# Epoch 82/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0059 - jacard_coef: 0.8661 - val_loss: 0.0128 - val_jacard_coef: 0.8693
# Epoch 83/103
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0061 - jacard_coef: 0.8685 - val_loss: 0.0103 - val_jacard_coef: 0.8754
# Epoch 84/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0058 - jacard_coef: 0.8661 - val_loss: 0.0111 - val_jacard_coef: 0.8729
# Epoch 85/103
# 131/131 [==============================] - 15s 114ms/step - loss: 0.0056 - jacard_coef: 0.8685 - val_loss: 0.0092 - val_jacard_coef: 0.8694
# Epoch 86/103
# 131/131 [==============================] - 16s 119ms/step - loss: 0.0058 - jacard_coef: 0.8697 - val_loss: 0.0116 - val_jacard_coef: 0.8967
# Epoch 87/103
# 131/131 [==============================] - 17s 130ms/step - loss: 0.0057 - jacard_coef: 0.8690 - val_loss: 0.0108 - val_jacard_coef: 0.8741
# Epoch 88/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0057 - jacard_coef: 0.8658 - val_loss: 0.0112 - val_jacard_coef: 0.8479
# Epoch 89/103
# 131/131 [==============================] - 15s 116ms/step - loss: 0.0064 - jacard_coef: 0.8508 - val_loss: 0.0118 - val_jacard_coef: 0.8597
# Epoch 90/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0056 - jacard_coef: 0.8629 - val_loss: 0.0091 - val_jacard_coef: 0.8702
# Epoch 91/103
#  89/131 [===================>..........] - ETA: 3s - loss: 0.0045 - jacard_coef: 0.8877
# Epoch 91: saving model to /content/drive/MyDrive/focal/cp-0091.ckpt
# 131/131 [==============================] - 15s 116ms/step - loss: 0.0059 - jacard_coef: 0.8705 - val_loss: 0.0123 - val_jacard_coef: 0.7871
# Epoch 92/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0066 - jacard_coef: 0.8491 - val_loss: 0.0098 - val_jacard_coef: 0.8735
# Epoch 93/103
# 131/131 [==============================] - 14s 107ms/step - loss: 0.0062 - jacard_coef: 0.8661 - val_loss: 0.0100 - val_jacard_coef: 0.8202
# Epoch 94/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0055 - jacard_coef: 0.8630 - val_loss: 0.0102 - val_jacard_coef: 0.8548
# Epoch 95/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0053 - jacard_coef: 0.8699 - val_loss: 0.0112 - val_jacard_coef: 0.8338
# Epoch 96/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0055 - jacard_coef: 0.8690 - val_loss: 0.0109 - val_jacard_coef: 0.8412
# Epoch 97/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0053 - jacard_coef: 0.8610 - val_loss: 0.0129 - val_jacard_coef: 0.8253
# Epoch 98/103
# 131/131 [==============================] - 14s 108ms/step - loss: 0.0054 - jacard_coef: 0.8586 - val_loss: 0.0106 - val_jacard_coef: 0.8058
# Epoch 99/103
# 131/131 [==============================] - 14s 111ms/step - loss: 0.0052 - jacard_coef: 0.8610 - val_loss: 0.0131 - val_jacard_coef: 0.8443
# Epoch 100/103
# 131/131 [==============================] - 15s 111ms/step - loss: 0.0053 - jacard_coef: 0.8742 - val_loss: 0.0138 - val_jacard_coef: 0.7992
# Epoch 101/103
#  99/131 [=====================>........] - ETA: 2s - loss: 0.0047 - jacard_coef: 0.8726
# Epoch 101: saving model to /content/drive/MyDrive/focal/cp-0101.ckpt
# 131/131 [==============================] - 15s 113ms/step - loss: 0.0054 - jacard_coef: 0.8631 - val_loss: 0.0115 - val_jacard_coef: 0.8706
# Epoch 102/103
# 131/131 [==============================] - 15s 112ms/step - loss: 0.0050 - jacard_coef: 0.8762 - val_loss: 0.0135 - val_jacard_coef: 0.8336
# Epoch 103/103
# 131/131 [==============================] - 14s 110ms/step - loss: 0.0050 - jacard_coef: 0.8729 - val_loss: 0.0123 - val_jacard_coef: 0.8398

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
for i in history.history.items():
  print(i)
# Out:
# ('loss', [0.07012619823217392, 0.026595160365104675, 0.024716565385460854, 0.022655779495835304, 0.021501846611499786, 0.020504523068666458, 0.019655602052807808, 0.018814176321029663, 0.018881576135754585, 0.01758730039000511, 0.017027245834469795, 0.016085196286439896, 0.015191788785159588, 0.015155843459069729, 0.014682602137327194, 0.014259593561291695, 0.013900003395974636, 0.013136950321495533, 0.012668373994529247, 0.012512974441051483, 0.01204659417271614, 0.011724020354449749, 0.011301659978926182, 0.01109193917363882, 0.01082970853894949, 0.010719114914536476, 0.010306512005627155, 0.010109374299645424, 0.009770135395228863, 0.010482803918421268, 0.010131710208952427, 0.00961568858474493, 0.009457752108573914, 0.009270391426980495, 0.009275693446397781, 0.009182548150420189, 0.008835164830088615, 0.008835066109895706, 0.00871817022562027, 0.008944939821958542, 0.00868569128215313, 0.008883396163582802, 0.008305668830871582, 0.008332435041666031, 0.008593235164880753, 0.008018345572054386, 0.008021876215934753, 0.007975690998136997, 0.0076609584502875805, 0.007865560241043568, 0.007966055534780025, 0.008217912167310715, 0.007606755010783672, 0.007440796121954918, 0.00801877398043871, 0.008127843961119652, 0.009115046821534634, 0.008552073501050472, 0.007738619111478329, 0.007011628709733486, 0.007104144897311926, 0.007218881510198116, 0.007033299654722214, 0.0072015258483588696, 0.007012112997472286, 0.007112725637853146, 0.007210534997284412, 0.007432013284415007, 0.0065605840645730495, 0.006941208150237799, 0.0067918067798018456, 0.006574802100658417, 0.006341373082250357, 0.0063828714191913605, 0.006256666965782642, 0.006267318967729807, 0.006562621332705021, 0.005944646894931793, 0.005782287567853928, 0.006131186615675688, 0.005593594629317522, 0.0058818720281124115, 0.006071118172258139, 0.0057601029984653, 0.005644065793603659, 0.005756437312811613, 0.005690013524144888, 0.005702641326934099, 0.006429027300328016, 0.005560414399951696, 0.005944281816482544, 0.006625923328101635, 0.006225788965821266, 0.005504771135747433, 0.005255201831459999, 0.005541365128010511, 0.005345918703824282, 0.00537573779001832, 0.005228199064731598, 0.005320585798472166, 0.005438520107418299, 0.004982959479093552, 0.004983273334801197])
# ('jacard_coef', [0.6772783398628235, 0.7683396339416504, 0.7600394487380981, 0.7692101001739502, 0.7758920192718506, 0.7810261845588684, 0.7877258062362671, 0.790051281452179, 0.7884658575057983, 0.7918891310691833, 0.7972286343574524, 0.7966865301132202, 0.8075764179229736, 0.8043556809425354, 0.8070188760757446, 0.8110998868942261, 0.8103062510490417, 0.8222392201423645, 0.8258107304573059, 0.826367199420929, 0.8273637294769287, 0.8281702399253845, 0.8315703272819519, 0.8244605660438538, 0.825718343257904, 0.8252156376838684, 0.8320271372795105, 0.8287394642829895, 0.8330249190330505, 0.8327174782752991, 0.8368584513664246, 0.8347355723381042, 0.8343581557273865, 0.8387326002120972, 0.8379880785942078, 0.8351166844367981, 0.8389260172843933, 0.8427566289901733, 0.8445327877998352, 0.8386837840080261, 0.8399701118469238, 0.8363704681396484, 0.8429079055786133, 0.8402019739151001, 0.8453028202056885, 0.8447631597518921, 0.8432547450065613, 0.8527494668960571, 0.850110650062561, 0.8487190008163452, 0.8500202894210815, 0.8461010456085205, 0.851899266242981, 0.852142870426178, 0.8438635468482971, 0.8444458842277527, 0.8427529335021973, 0.8392876982688904, 0.8472211956977844, 0.8559970855712891, 0.8534119725227356, 0.8505115509033203, 0.8479256629943848, 0.853476345539093, 0.8530356287956238, 0.8554290533065796, 0.852588415145874, 0.8489229679107666, 0.8622633218765259, 0.8514626622200012, 0.8455735445022583, 0.858735978603363, 0.862014651298523, 0.8598576188087463, 0.8567566871643066, 0.8583291172981262, 0.8564990758895874, 0.8575820922851562, 0.8619580864906311, 0.8654031157493591, 0.8663468360900879, 0.866141140460968, 0.8684737086296082, 0.8660711050033569, 0.8684784173965454, 0.8697049021720886, 0.868977427482605, 0.8658324480056763, 0.850770890712738, 0.8628900647163391, 0.8705066442489624, 0.8491383194923401, 0.866075873374939, 0.8629586100578308, 0.8698928356170654, 0.8690330982208252, 0.8609618544578552, 0.8585674166679382, 0.8609821796417236, 0.8741573095321655, 0.8631467819213867, 0.8761559724807739, 0.8729481101036072])
# ('val_loss', [0.049949441105127335, 0.025754785165190697, 0.024708671495318413, 0.02743038348853588, 0.02720119245350361, 0.025835659354925156, 0.024334413930773735, 0.023171091452240944, 0.023530229926109314, 0.019108135253190994, 0.018557682633399963, 0.016830118373036385, 0.01618250086903572, 0.017176510766148567, 0.01858457736670971, 0.020800502970814705, 0.01732000522315502, 0.017825769260525703, 0.015352511778473854, 0.015602712519466877, 0.013450847007334232, 0.013067936524748802, 0.013243448920547962, 0.013499119319021702, 0.011906510218977928, 0.011835426092147827, 0.011215217411518097, 0.010546562261879444, 0.011420057155191898, 0.01161997765302658, 0.010866943746805191, 0.011065864935517311, 0.01125616580247879, 0.011085198260843754, 0.010342763736844063, 0.010729116387665272, 0.010614041239023209, 0.0108494246378541, 0.01189296692609787, 0.010636215098202229, 0.011284184642136097, 0.010685962624847889, 0.011777738109230995, 0.01073720958083868, 0.010040556080639362, 0.009887964464724064, 0.013769768178462982, 0.011029821820557117, 0.013727125711739063, 0.010475912131369114, 0.012672279961407185, 0.011715451255440712, 0.011824045330286026, 0.01381112914532423, 0.009757911786437035, 0.015094009228050709, 0.011835504323244095, 0.013122285716235638, 0.010271923616528511, 0.00983431562781334, 0.010873353108763695, 0.010781883262097836, 0.010628931224346161, 0.011205478571355343, 0.010937768965959549, 0.010465145111083984, 0.011011013761162758, 0.010114078409969807, 0.011666118167340755, 0.011449882760643959, 0.011500395834445953, 0.01188677828758955, 0.011155422776937485, 0.01198426354676485, 0.012427209876477718, 0.012808279134333134, 0.010257533751428127, 0.010505370795726776, 0.010582535527646542, 0.00981615949422121, 0.01089564524590969, 0.012831777334213257, 0.010302667506039143, 0.011116201058030128, 0.009247231297194958, 0.011570747010409832, 0.01081552542746067, 0.01115022785961628, 0.011848529800772667, 0.009061693213880062, 0.012331095524132252, 0.009795693680644035, 0.009959221817553043, 0.010158352553844452, 0.01116435881704092, 0.010888896882534027, 0.012867128476500511, 0.01062975637614727, 0.013128982856869698, 0.01376525778323412, 0.011468634940683842, 0.013456233777105808, 0.012343542650341988])
# ('val_jacard_coef', [0.823620080947876, 0.7901434898376465, 0.762305498123169, 0.6450895071029663, 0.6146249175071716, 0.6005014181137085, 0.6289586424827576, 0.6510860323905945, 0.6125829219818115, 0.7232154607772827, 0.718466579914093, 0.7661374807357788, 0.7890360951423645, 0.8088235259056091, 0.8360600471496582, 0.8571125864982605, 0.8566627502441406, 0.8580071926116943, 0.8570611476898193, 0.8436973690986633, 0.8398445844650269, 0.827223539352417, 0.8062692284584045, 0.7821875214576721, 0.8075019121170044, 0.7877684831619263, 0.8118000030517578, 0.8108530640602112, 0.8041071891784668, 0.8182722330093384, 0.8412995934486389, 0.821298360824585, 0.8292791843414307, 0.8337650299072266, 0.8460944890975952, 0.8042808771133423, 0.8543109893798828, 0.8646831512451172, 0.9023694396018982, 0.8761492967605591, 0.834972620010376, 0.8625919222831726, 0.859149158000946, 0.8904685974121094, 0.8387661576271057, 0.8557428121566772, 0.8380982875823975, 0.8690689206123352, 0.8582344651222229, 0.8651480078697205, 0.8253051042556763, 0.8436084985733032, 0.8548670411109924, 0.8181877136230469, 0.856472373008728, 0.8417394161224365, 0.7699171304702759, 0.8460812568664551, 0.8595403432846069, 0.8572337627410889, 0.8519881367683411, 0.816094160079956, 0.8646975755691528, 0.8498829007148743, 0.8606555461883545, 0.8743277192115784, 0.8708264827728271, 0.8960697054862976, 0.8797560930252075, 0.8730740547180176, 0.8883122205734253, 0.8734435439109802, 0.8853979706764221, 0.8702600598335266, 0.8760695457458496, 0.8758751153945923, 0.8738526105880737, 0.8639381527900696, 0.8801749348640442, 0.8650261163711548, 0.8864256143569946, 0.8693338632583618, 0.8754146695137024, 0.8728787302970886, 0.8693581223487854, 0.8967009782791138, 0.874143660068512, 0.8479492664337158, 0.8596989512443542, 0.8701825737953186, 0.7870568633079529, 0.8734779357910156, 0.8202274441719055, 0.8547914624214172, 0.8338184952735901, 0.8411694169044495, 0.8253227472305298, 0.8057766556739807, 0.8443254232406616, 0.7992110252380371, 0.8705642223358154, 0.8335705399513245, 0.8397636413574219])

# %%
acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
np.save("/content/drive/MyDrive/focal/training_loss.npy",np.array(loss))
np.save("/content/drive/MyDrive/focal/val_loss.npy",np.array(val_loss))
np.save("/content/drive/MyDrive/focal/training_jaccard.npy",np.array(acc))
np.save("/content/drive/MyDrive/focal/val_jaccard.npy",np.array(val_acc))
np.save("/content/drive/MyDrive/focal/epochs.npy",range(1, len(np.array(loss)) + 1))

# %%
# loss_1 = np.load("/content/drive/MyDrive/small_UNET_models/training_loss.npy")
# epoch_1 = np.load("/content/drive/MyDrive/small_UNET_models/epochs.npy")

# plt.plot(epoch_1, loss_1, 'y', label='Training loss')
# # plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
img, msk = val_img_datagen.__next__()

# %% [markdown]
# ##making predictions on test dataset

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img)-1)#6 is good
# test_img_number = 6
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(233)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# focal_loss = FocalLoss()
# loss = focal_loss.call(ground_truth, predicted_img)
# print(loss)
# # IOU = jacard_coef(ground_truth, predicted_img)
# # print(IOU)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# (1, 240, 240, 4)
# (240, 240, 4)

# %% [markdown]
# ##Loading the last checkpoint

# %%
model = multi_unet_model()
model.compile(optimizer='adam', loss= FocalLoss(), metrics=[jacard_coef])

# Load the previously saved weights
model.load_weights("/content/drive/MyDrive/focal/cp-0031.ckpt")

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img)-1)#6 is good
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image 1')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Testing Image 2')
plt.imshow(test_img[:,:,1], cmap='gray') #only the first channel is displayed

plt.subplot(233)
plt.title('Testing Image 3')
plt.imshow(test_img[:,:,2], cmap='gray') #only the first channel is displayed

plt.subplot(234)
plt.title('Testing Image 4')
plt.imshow(test_img[:,:,3], cmap='gray') #only the first channel is displayed

plt.subplot(235)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(236)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()
# Out:
# 1/1 [==============================] - 0s 128ms/step
# (1, 240, 240, 4)
# (240, 240, 4)
