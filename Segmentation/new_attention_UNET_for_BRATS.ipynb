# %% [markdown]
# <a href="https://colab.research.google.com/github/MilanBandara/FYP/blob/main/new_attention_UNET_for_BRATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting Drive
from google.colab import drive
import numpy as np
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import to_categorical

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Creating the data generator

# %%
def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("Image - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def load_msk(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):
            image = np.load(img_dir+image_name)
            # print("before - ",image.shape)
            image = to_categorical(image, num_classes=4)
            # print("After - ",image.shape)
            images.append(image)
    images = np.array(images)

    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)

            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_msk(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples
            batch_start += batch_size
            batch_end += batch_size

# %% [markdown]
# #Making the data generator

# %%
train_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_data/"
train_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_data/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_validation/"
val_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_validation/"
val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 8

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,
                                val_mask_dir, val_mask_list, batch_size)

# %% [markdown]
# #Verifying the generator

# %%
#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = val_img_datagen.__next__()

# %% [markdown]
# #Visualizing the loaded images

# %%
import random
data_point = random.randint(0, batch_size)
# data_point = 3

original_labels = np.expand_dims(msk[data_point,:,:,:], axis=0)
original_labels = np.argmax(original_labels, axis=3)


plt.subplot(341)
plt.imshow(img[data_point,:,:,0], cmap='gray')
plt.title('Image t1c')
plt.subplot(342)
plt.imshow(img[data_point,:,:,1], cmap='gray')
plt.title('Image t1n')
plt.subplot(343)
plt.imshow(img[data_point,:,:,2], cmap='gray')
plt.title('Image t2f')
plt.subplot(344)
plt.imshow(img[data_point,:,:,3], cmap='gray')
plt.title('Image t2w')
plt.subplot(345)
plt.imshow(msk[data_point,:,:,0], cmap='gray')
plt.title('Label_1')
plt.subplot(346)
plt.imshow(msk[data_point,:,:,1], cmap='gray')
plt.title('Label_2')
plt.subplot(347)
plt.imshow(msk[data_point,:,:,2], cmap='gray')
plt.title('Label_3')
plt.subplot(348)
plt.imshow(msk[data_point,:,:,3], cmap='gray')
plt.title('Label_4')
plt.subplot(349)
plt.imshow(original_labels.reshape((240,240)))
plt.title('Complete label')
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.show()

# %% [markdown]
# ##Attention blocks

# %%
# https://youtu.be/L5iV5BHkMzM
"""

Attention U-net:
https://arxiv.org/pdf/1804.03999.pdf

Recurrent residual Unet (R2U-Net) paper
https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
(Check fig 4.)

Note: Batch normalization should be performed over channels after a convolution,
In the following code axis is set to 3 as our inputs are of shape
[None, height, width, channel]. Channel is axis=3.

Original code from below link but heavily modified.
https://github.com/MoleImg/Attention_UNet/blob/master/AttResUNet.py
"""

import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K



'''
A few useful metrics and losses
'''

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


##############################################################
'''
Useful blocks to build Unet

conv - BN - Activation - conv - BN - Activation - Dropout (if enabled)

'''


def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).

    1. conv - BN - Activation - conv - BN - Activation
                                          - shortcut  - BN - shortcut+BN

    2. conv - BN - Activation - conv - BN
                                     - shortcut  - BN - shortcut+BN - Activation

    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %% [markdown]
# ##Attention UNET

# %%
def attention_unet_model(batch_norm = True):
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5) #deepest conv block

    #Expansive path
    #create a gating signal
    gating_6 = gating_signal(c5, 128, batch_norm = True) #feed this and c4 to attention block
    #getting the output from attention block by feeding gating signal and c4
    att_6 = attention_block(c4, gating_6, 128)
    #Conv2DTranspose the deepest block c5
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5) #this is correct
    #concatanate the upsampled block and the the output from the attention block
    u6 = concatenate([u6, att_6])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    gating_7 = gating_signal(c6, 64, batch_norm = True)
    att_7 = attention_block(c3,gating_7,64)
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, att_7])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    gating_8 = gating_signal(c7, 32, batch_norm = True)
    att_8 = attention_block(c2,gating_8,32)
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, att_8])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    gating_9 = gating_signal(c8, 16, batch_norm = True)
    att_9 = attention_block(c1,gating_9,16)
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, att_9], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
def multi_unet_model():
#Build the model
    inputs = Input((240, 240, 4))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.3)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.3)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.4)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.4)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.4)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.4)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.3)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.3)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(4, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
###############################################################
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(train_masks_reshaped_encoded),
#                                                  train_masks_reshaped_encoded)
# print("Class weights are...:", class_weights)

# %% [markdown]
# #Defining loss functions

# %%
from keras import backend as K
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)  # -1 ultiplied as we want to minimize this value as loss function

# # Typical tf.keras API usage
# import tensorflow as tf
# from focal_loss import BinaryFocalLoss,SparseCategoricalFocalLoss

# %%
# import segmentation_models_3D as sm
# # dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3]))
# focal_loss = sm.losses.CategoricalFocalLoss()
# # total_loss = dice_loss + (1 * focal_loss)

# %%
import tensorflow as tf

class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, alpha=0.25, gamma=4.0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def call(self, y_true, y_pred):
        """
        Inputs and targets should be of shape (batch_size, num_classes, height, width)
        """

        # Calculate the cross-entropy loss
        ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)

        # Calculate the scaling factor
        pt = tf.math.exp(-ce_loss)
        scaling_factor = (1 - pt) ** self.gamma

        # Calculate the Focal loss
        focal_loss = scaling_factor * ce_loss

        # Return the average Focal loss over the batch
        return tf.reduce_mean(focal_loss)

# %% [markdown]
# ##Creating a Checkpoint

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "/content/drive/MyDrive/focal_att/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Calculate the number of batches per epoch
import math
n_batches = 1051 / batch_size
n_batches = math.ceil(n_batches)    # round up the number of batches to the nearest whole integer

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=10*n_batches)

# %%
from tensorflow.keras.callbacks import TensorBoard
file_name = 'my_saved_model'  #Give unique name each time, otherwise results get concatenated
#Try running multiple times and see the output in tensorboard
#If file name is changed, you can select the specific model in TensorBoard
tensorboard = TensorBoard(log_dir= f"/content/drive/MyDrive/focal_att/{file_name}")

# %%
IMG_HEIGHT = 240
IMG_WIDTH  =  240
IMG_CHANNELS = 4

def get_model():
    return attention_unet_model()

model = get_model()
model.compile(optimizer='adam', loss= FocalLoss(), metrics=[jacard_coef])
# model.compile(optimizer='adam', loss=focal_loss, metrics=[jacard_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 4)]        0         []
#
#  conv2d (Conv2D)             (None, 240, 240, 16)         592       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 240, 240, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 240, 240, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 120, 120, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 120, 120, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 60, 60, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 30, 30, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 15, 15, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 15, 15, 128)          32896     ['conv2d_9[0][0]']
#
#  batch_normalization (Batch  (None, 15, 15, 128)          512       ['conv2d_10[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 15, 15, 128)          0         ['batch_normalization[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 15, 15, 128)          16512     ['activation[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 15, 15, 128)          147584    ['conv2d_12[0][0]']
#  anspose)
#
#  conv2d_11 (Conv2D)          (None, 15, 15, 128)          65664     ['conv2d_7[0][0]']
#
#  add (Add)                   (None, 15, 15, 128)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_1 (Activation)   (None, 15, 15, 128)          0         ['add[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 15, 15, 1)            129       ['activation_1[0][0]']
#
#  activation_2 (Activation)   (None, 15, 15, 1)            0         ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 30, 30, 1)            0         ['activation_2[0][0]']
#  D)
#
#  lambda (Lambda)             (None, 30, 30, 128)          0         ['up_sampling2d[0][0]']
#
#  multiply (Multiply)         (None, 30, 30, 128)          0         ['lambda[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 30, 30, 128)          16512     ['multiply[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 30, 30, 128)          131200    ['conv2d_9[0][0]']
#  Transpose)
#
#  batch_normalization_1 (Bat  (None, 30, 30, 128)          512       ['conv2d_14[0][0]']
#  chNormalization)
#
#  concatenate (Concatenate)   (None, 30, 30, 256)          0         ['conv2d_transpose_1[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_15 (Conv2D)          (None, 30, 30, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 30, 30, 128)          0         ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 30, 30, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 30, 30, 64)           8256      ['conv2d_16[0][0]']
#
#  batch_normalization_2 (Bat  (None, 30, 30, 64)           256       ['conv2d_17[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 30, 30, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_19 (Conv2D)          (None, 30, 30, 64)           4160      ['activation_3[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 30, 30, 64)           36928     ['conv2d_19[0][0]']
#  Transpose)
#
#  conv2d_18 (Conv2D)          (None, 30, 30, 64)           16448     ['conv2d_5[0][0]']
#
#  add_1 (Add)                 (None, 30, 30, 64)           0         ['conv2d_transpose_2[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  activation_4 (Activation)   (None, 30, 30, 64)           0         ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 30, 30, 1)            65        ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 30, 30, 1)            0         ['conv2d_20[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 60, 60, 1)            0         ['activation_5[0][0]']
#  g2D)
#
#  lambda_1 (Lambda)           (None, 60, 60, 64)           0         ['up_sampling2d_1[0][0]']
#
#  multiply_1 (Multiply)       (None, 60, 60, 64)           0         ['lambda_1[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 60, 60, 64)           4160      ['multiply_1[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 60, 60, 64)           32832     ['conv2d_16[0][0]']
#  Transpose)
#
#  batch_normalization_3 (Bat  (None, 60, 60, 64)           256       ['conv2d_21[0][0]']
#  chNormalization)
#
#  concatenate_1 (Concatenate  (None, 60, 60, 128)          0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_22 (Conv2D)          (None, 60, 60, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 60, 60, 64)           0         ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 60, 60, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 60, 60, 32)           2080      ['conv2d_23[0][0]']
#
#  batch_normalization_4 (Bat  (None, 60, 60, 32)           128       ['conv2d_24[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 60, 60, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_26 (Conv2D)          (None, 60, 60, 32)           1056      ['activation_6[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 60, 60, 32)           9248      ['conv2d_26[0][0]']
#  Transpose)
#
#  conv2d_25 (Conv2D)          (None, 60, 60, 32)           4128      ['conv2d_3[0][0]']
#
#  add_2 (Add)                 (None, 60, 60, 32)           0         ['conv2d_transpose_4[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  activation_7 (Activation)   (None, 60, 60, 32)           0         ['add_2[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 60, 60, 1)            33        ['activation_7[0][0]']
#
#  activation_8 (Activation)   (None, 60, 60, 1)            0         ['conv2d_27[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 120, 120, 1)          0         ['activation_8[0][0]']
#  g2D)
#
#  lambda_2 (Lambda)           (None, 120, 120, 32)         0         ['up_sampling2d_2[0][0]']
#
#  multiply_2 (Multiply)       (None, 120, 120, 32)         0         ['lambda_2[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 120, 120, 32)         1056      ['multiply_2[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 120, 120, 32)         8224      ['conv2d_23[0][0]']
#  Transpose)
#
#  batch_normalization_5 (Bat  (None, 120, 120, 32)         128       ['conv2d_28[0][0]']
#  chNormalization)
#
#  concatenate_2 (Concatenate  (None, 120, 120, 64)         0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_29 (Conv2D)          (None, 120, 120, 32)         18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 120, 120, 32)         0         ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 120, 120, 32)         9248      ['dropout_7[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 120, 120, 16)         528       ['conv2d_30[0][0]']
#
#  batch_normalization_6 (Bat  (None, 120, 120, 16)         64        ['conv2d_31[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 120, 120, 16)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_33 (Conv2D)          (None, 120, 120, 16)         272       ['activation_9[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 120, 120, 16)         2320      ['conv2d_33[0][0]']
#  Transpose)
#
#  conv2d_32 (Conv2D)          (None, 120, 120, 16)         1040      ['conv2d_1[0][0]']
#
#  add_3 (Add)                 (None, 120, 120, 16)         0         ['conv2d_transpose_6[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  activation_10 (Activation)  (None, 120, 120, 16)         0         ['add_3[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 120, 120, 1)          17        ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 120, 120, 1)          0         ['conv2d_34[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 240, 240, 1)          0         ['activation_11[0][0]']
#  g2D)
#
#  lambda_3 (Lambda)           (None, 240, 240, 16)         0         ['up_sampling2d_3[0][0]']
#
#  multiply_3 (Multiply)       (None, 240, 240, 16)         0         ['lambda_3[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 240, 240, 16)         272       ['multiply_3[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 240, 240, 16)         2064      ['conv2d_30[0][0]']
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 240, 240, 16)         64        ['conv2d_35[0][0]']
#  chNormalization)
#
#  concatenate_3 (Concatenate  (None, 240, 240, 32)         0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_36 (Conv2D)          (None, 240, 240, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 240, 240, 16)         0         ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 240, 240, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 240, 240, 4)          68        ['conv2d_37[0][0]']
#
# ==================================================================================================
# Total params: 2314584 (8.83 MB)
# Trainable params: 2313624 (8.83 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
history = model.fit(train_img_datagen,
                    steps_per_epoch=steps_per_epoch,
                    verbose=1,
                    epochs=103,
                    validation_data=val_img_datagen,
                    validation_steps=val_steps_per_epoch,
                    callbacks=[cp_callback,tensorboard],
                    shuffle=False)
# Out:
# Epoch 1/103
# 131/131 [==============================] - 1487s 11s/step - loss: 0.0432 - jacard_coef: 0.7776 - val_loss: 0.0777 - val_jacard_coef: 0.6631
# Epoch 2/103
# 131/131 [==============================] - 27s 185ms/step - loss: 0.0265 - jacard_coef: 0.8014 - val_loss: 0.0653 - val_jacard_coef: 0.6755
# Epoch 3/103
# 131/131 [==============================] - 25s 188ms/step - loss: 0.0256 - jacard_coef: 0.8011 - val_loss: 0.0451 - val_jacard_coef: 0.7221
# Epoch 4/103
# 131/131 [==============================] - 25s 189ms/step - loss: 0.0248 - jacard_coef: 0.8016 - val_loss: 0.0393 - val_jacard_coef: 0.7964
# Epoch 5/103
# 131/131 [==============================] - 29s 224ms/step - loss: 0.0240 - jacard_coef: 0.8032 - val_loss: 0.0317 - val_jacard_coef: 0.8528
# Epoch 6/103
# 131/131 [==============================] - 22s 170ms/step - loss: 0.0228 - jacard_coef: 0.8059 - val_loss: 0.0313 - val_jacard_coef: 0.8636
# Epoch 7/103
# 131/131 [==============================] - 25s 187ms/step - loss: 0.0216 - jacard_coef: 0.8097 - val_loss: 0.0355 - val_jacard_coef: 0.8670
# Epoch 8/103
# 131/131 [==============================] - 27s 206ms/step - loss: 0.0201 - jacard_coef: 0.8144 - val_loss: 0.0297 - val_jacard_coef: 0.8365
# Epoch 9/103
# 131/131 [==============================] - 23s 175ms/step - loss: 0.0189 - jacard_coef: 0.8146 - val_loss: 0.0225 - val_jacard_coef: 0.7721
# Epoch 10/103
# 131/131 [==============================] - 26s 202ms/step - loss: 0.0186 - jacard_coef: 0.8065 - val_loss: 0.0218 - val_jacard_coef: 0.7809
# Epoch 11/103
#   9/131 [=>............................] - ETA: 14s - loss: 0.0180 - jacard_coef: 0.8092
# Epoch 11: saving model to /content/drive/MyDrive/focal_att/cp-0011.ckpt
# 131/131 [==============================] - 28s 217ms/step - loss: 0.0178 - jacard_coef: 0.8150 - val_loss: 0.0220 - val_jacard_coef: 0.7752
# Epoch 12/103
# 131/131 [==============================] - 26s 201ms/step - loss: 0.0171 - jacard_coef: 0.8107 - val_loss: 0.0248 - val_jacard_coef: 0.8074
# Epoch 13/103
# 131/131 [==============================] - 26s 201ms/step - loss: 0.0163 - jacard_coef: 0.8175 - val_loss: 0.0314 - val_jacard_coef: 0.8334
# Epoch 14/103
# 131/131 [==============================] - 26s 200ms/step - loss: 0.0159 - jacard_coef: 0.8187 - val_loss: 0.0270 - val_jacard_coef: 0.8216
# Epoch 15/103
# 131/131 [==============================] - 24s 186ms/step - loss: 0.0154 - jacard_coef: 0.8221 - val_loss: 0.0321 - val_jacard_coef: 0.8449
# Epoch 16/103
# 131/131 [==============================] - 29s 224ms/step - loss: 0.0148 - jacard_coef: 0.8225 - val_loss: 0.0256 - val_jacard_coef: 0.8445
# Epoch 17/103
# 131/131 [==============================] - 27s 209ms/step - loss: 0.0149 - jacard_coef: 0.8237 - val_loss: 0.0206 - val_jacard_coef: 0.8605
# Epoch 18/103
# 131/131 [==============================] - 27s 208ms/step - loss: 0.0141 - jacard_coef: 0.8262 - val_loss: 0.0233 - val_jacard_coef: 0.8770
# Epoch 19/103
# 131/131 [==============================] - 28s 212ms/step - loss: 0.0140 - jacard_coef: 0.8259 - val_loss: 0.0214 - val_jacard_coef: 0.8554
# Epoch 20/103
# 131/131 [==============================] - 26s 195ms/step - loss: 0.0135 - jacard_coef: 0.8241 - val_loss: 0.0234 - val_jacard_coef: 0.8746
# Epoch 21/103
#  19/131 [===>..........................] - ETA: 13s - loss: 0.0146 - jacard_coef: 0.8206
# Epoch 21: saving model to /content/drive/MyDrive/focal_att/cp-0021.ckpt
# 131/131 [==============================] - 29s 223ms/step - loss: 0.0137 - jacard_coef: 0.8252 - val_loss: 0.0263 - val_jacard_coef: 0.8627
# Epoch 22/103
# 131/131 [==============================] - 31s 235ms/step - loss: 0.0134 - jacard_coef: 0.8237 - val_loss: 0.0202 - val_jacard_coef: 0.8601
# Epoch 23/103
# 131/131 [==============================] - 29s 221ms/step - loss: 0.0128 - jacard_coef: 0.8276 - val_loss: 0.0267 - val_jacard_coef: 0.8709
# Epoch 24/103
# 131/131 [==============================] - 29s 221ms/step - loss: 0.0128 - jacard_coef: 0.8290 - val_loss: 0.0403 - val_jacard_coef: 0.8800
# Epoch 25/103
# 131/131 [==============================] - 28s 214ms/step - loss: 0.0124 - jacard_coef: 0.8336 - val_loss: 0.0464 - val_jacard_coef: 0.8828
# Epoch 26/103
# 131/131 [==============================] - 30s 230ms/step - loss: 0.0123 - jacard_coef: 0.8346 - val_loss: 0.0497 - val_jacard_coef: 0.8713
# Epoch 27/103
# 131/131 [==============================] - 29s 223ms/step - loss: 0.0123 - jacard_coef: 0.8308 - val_loss: 0.0413 - val_jacard_coef: 0.8724
# Epoch 28/103
# 131/131 [==============================] - 28s 214ms/step - loss: 0.0121 - jacard_coef: 0.8396 - val_loss: 0.0942 - val_jacard_coef: 0.9073
# Epoch 29/103
# 131/131 [==============================] - 31s 236ms/step - loss: 0.0114 - jacard_coef: 0.8406 - val_loss: 0.1011 - val_jacard_coef: 0.9113
# Epoch 30/103
# 131/131 [==============================] - 26s 202ms/step - loss: 0.0113 - jacard_coef: 0.8414 - val_loss: 0.0989 - val_jacard_coef: 0.9184
# Epoch 31/103
#  29/131 [=====>........................] - ETA: 12s - loss: 0.0103 - jacard_coef: 0.8457
# Epoch 31: saving model to /content/drive/MyDrive/focal_att/cp-0031.ckpt
# 131/131 [==============================] - 32s 241ms/step - loss: 0.0114 - jacard_coef: 0.8421 - val_loss: 0.1038 - val_jacard_coef: 0.9134
# Epoch 32/103
# 131/131 [==============================] - 28s 213ms/step - loss: 0.0112 - jacard_coef: 0.8437 - val_loss: 0.1268 - val_jacard_coef: 0.9121
# Epoch 33/103
# 131/131 [==============================] - 31s 241ms/step - loss: 0.0113 - jacard_coef: 0.8479 - val_loss: 0.0718 - val_jacard_coef: 0.8962
# Epoch 34/103
# 131/131 [==============================] - 30s 228ms/step - loss: 0.0111 - jacard_coef: 0.8519 - val_loss: 0.0475 - val_jacard_coef: 0.9011
# Epoch 35/103
# 131/131 [==============================] - 29s 221ms/step - loss: 0.0113 - jacard_coef: 0.8549 - val_loss: 0.0587 - val_jacard_coef: 0.9050
# Epoch 36/103
# 131/131 [==============================] - ETA: 0s - loss: 0.0106 - jacard_coef: 0.8581
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-c898a2d0f8f9> in <cell line: 1>()
# ----> 1 history = model.fit(train_img_datagen,
#       2                     steps_per_epoch=steps_per_epoch,
#       3                     verbose=1,
#       4                     epochs=103,
#       5                     validation_data=val_img_datagen,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1789                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1790                         )
# -> 1791                     val_logs = self.evaluate(
#    1792                         x=val_x,
#    1793                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2198                         ):
#    2199                             callbacks.on_test_batch_begin(step)
# -> 2200                             logs = test_function_runner.run_step(
#    2201                                 dataset_or_iterator,
#    2202                                 data_handler,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    3998
#    3999     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4000         tmp_logs = self._function(dataset_or_iterator)
#    4001         if data_handler.should_sync:
#    4002             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     823
#     824       with OptionalXlaContext(self._jit_compile):
# --> 825         result = self._call(*args, **kwds)
#     826
#     827       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     862       # In this case we have not created variables on the first call. So we can
#     863       # run the first trace but we should fail if variables are created.
# --> 864       results = self._variable_creation_fn(*args, **kwds)
#     865       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     866         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     146       (concrete_function,
#     147        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148     return concrete_function._call_flat(
#     149         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     150
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs)
#    1347         and executing_eagerly):
#    1348       # No tape is watching; skip to running the function.
# -> 1349       return self._build_call_outputs(self._inference_function(*args))
#    1350     forward_backward = self._select_forward_and_backward_functions(
#    1351         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     194         with record.stop_recording():
#     195           if self._bound_context.executing_eagerly():
# --> 196             outputs = self._bound_context.call_function(
#     197                 self.name,
#     198                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1455     cancellation_context = cancellation.context()
#    1456     if cancellation_context is None:
# -> 1457       outputs = execute.execute(
#    1458           name.decode("utf-8"),
#    1459           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
for i in history.history.items():
  print(i)

# %%
acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
np.save("/content/drive/MyDrive/focal_att/training_loss.npy",np.array(loss))
np.save("/content/drive/MyDrive/focal_att/val_loss.npy",np.array(val_loss))
np.save("/content/drive/MyDrive/focal_att/training_jaccard.npy",np.array(acc))
np.save("/content/drive/MyDrive/focal_att/val_jaccard.npy",np.array(val_acc))
np.save("/content/drive/MyDrive/focal_att/epochs.npy",range(1, len(np.array(loss)) + 1))

# %%
# loss_1 = np.load("/content/drive/MyDrive/small_attention_UNET_models/training_loss.npy")
# epoch_1 = np.load("/content/drive/MyDrive/small_attention_UNET_models/epochs.npy")

# plt.plot(epoch_1, loss_1, 'y', label='Training loss')
# # plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
img, msk = val_img_datagen.__next__()

# %% [markdown]
# ##making predictions on test dataset

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img))#6 is good
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(233)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()

# focal_loss = FocalLoss()
# loss = focal_loss.call(ground_truth, predicted_img)
# print(loss)
# # IOU = jacard_coef(ground_truth, predicted_img)
# # print(IOU)

# %%
# %reload_ext tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=f"/content/drive/MyDrive/small_attention_UNET_models/{file_name}" --port=8008

# %% [markdown]
# IOU of around 93-94 and loss around 0.0020 - 0.0030 are good for training data, If this can be achived for validation data network will perform well

# %% [markdown]
# ##Loading the last checkpoint

# %%
model = attention_unet_model()
model.compile(optimizer='adam', loss= FocalLoss(), metrics=[jacard_coef])

# Load the previously saved weights
model.load_weights("/content/drive/MyDrive/focal_att/cp-0011.ckpt")

# %%
val_img_dir = "/content/drive/MyDrive/BRATS_train_data/X_validation/"
val_mask_dir = "/content/drive/MyDrive/BRATS_train_data/Y_validation/"
val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 8
val_img_datagen = imageLoader(val_img_dir, val_img_list,
                                val_mask_dir, val_mask_list, batch_size)

# %%
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')
img, msk = val_img_datagen.__next__()
import random
test_img_number = random.randint(0, len(img)-1)#6 is good
test_img = img[test_img_number]
ground_truth=msk[test_img_number]
# test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
print(prediction.shape)
print(ground_truth.shape)


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image 1')
plt.imshow(test_img[:,:,0], cmap='gray') #only the first channel is displayed

plt.subplot(232)
plt.title('Testing Image 2')
plt.imshow(test_img[:,:,1], cmap='gray') #only the first channel is displayed

plt.subplot(233)
plt.title('Testing Image 3')
plt.imshow(test_img[:,:,2], cmap='gray') #only the first channel is displayed

plt.subplot(234)
plt.title('Testing Image 4')
plt.imshow(test_img[:,:,3], cmap='gray') #only the first channel is displayed

plt.subplot(235)
plt.title('Original Label')
displayed_label = np.argmax(ground_truth, axis=2)
plt.imshow(displayed_label, cmap='jet')

plt.subplot(236)
plt.title('Predicted Label')
plt.imshow(predicted_img, cmap='jet')
plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step
# (1, 240, 240, 4)
# (240, 240, 4)

# %% [markdown]
# ##Performs well when there are not much small parts

# %%
# !pip install focal-loss

# %%
import tensorflow as tf
from focal_loss import BinaryFocalLoss,SparseCategoricalFocalLoss

# %%
loss = SparseCategoricalFocalLoss(gamma = 2)
focal = loss(prediction,ground_truth)
print(focal)
